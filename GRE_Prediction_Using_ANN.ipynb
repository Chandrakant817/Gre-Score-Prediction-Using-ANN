# %%
#Let's start with importing necessary libraries

import pandas as pd 
import numpy as np 
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model  import Ridge,Lasso,RidgeCV, LassoCV, ElasticNet, ElasticNetCV, LinearRegression
from sklearn.model_selection import train_test_split
#import statsmodels.api as sm 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data =pd.read_csv('/content/Admission_Prediction.csv')
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1      337.0        118.0                4.0  4.5  4.5  9.65
# 1           2      324.0        107.0                4.0  4.0  4.5  8.87
# 2           3        NaN        104.0                3.0  3.0  3.5  8.00
# 3           4      322.0        110.0                3.0  3.5  2.5  8.67
# 4           5      314.0        103.0                2.0  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
data.describe(include='all')
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  485.000000   490.000000         485.000000  500.000000
# mean   250.500000  316.558763   107.187755           3.121649    3.374000
# std    144.481833   11.274704     6.112899           1.146160    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR        CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000        500.00000
# mean     3.48400    8.576440    0.560000          0.72174
# std      0.92545    0.604813    0.496884          0.14114
# min      1.00000    6.800000    0.000000          0.34000
# 25%      3.00000    8.127500    0.000000          0.63000
# 50%      3.50000    8.560000    1.000000          0.72000
# 75%      4.00000    9.040000    1.000000          0.82000
# max      5.00000    9.920000    1.000000          0.97000

# %%
data.shape
# Out:
# (500, 9)

# %%
data.isnull().sum()
# Out:
# Serial No.            0
# GRE Score            15
# TOEFL Score          10
# University Rating    15
# SOP                   0
# LOR                   0
# CGPA                  0
# Research              0
# Chance of Admit       0
# dtype: int64

# %%
plt.figure(figsize = (9,7))
sns.heatmap(data.corr())

# %%
sns.pairplot(data)

# %% [markdown]
# **Filling Missing Values**

# %%
data['University Rating'] = data['University Rating'].fillna(data['University Rating'].mode()[0])
data['TOEFL Score'] = data['TOEFL Score'].fillna(data['TOEFL Score'].mean())
data['GRE Score']  = data['GRE Score'].fillna(data['GRE Score'].mean())

# %%
data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.558763   107.187755           3.118000    3.374000
# std    144.481833   11.103952     6.051338           1.128993    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  309.000000   103.000000           2.000000    2.500000
# 50%    250.500000  316.558763   107.000000           3.000000    3.500000
# 75%    375.250000  324.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR        CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000        500.00000
# mean     3.48400    8.576440    0.560000          0.72174
# std      0.92545    0.604813    0.496884          0.14114
# min      1.00000    6.800000    0.000000          0.34000
# 25%      3.00000    8.127500    0.000000          0.63000
# 50%      3.50000    8.560000    1.000000          0.72000
# 75%      4.00000    9.040000    1.000000          0.82000
# max      5.00000    9.920000    1.000000          0.97000

# %%
data.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# Now the data looks good and there are no missing values. Also, the first cloumn is just serial numbers, so we don' need that column. Let's drop it from data and make it more clean.

# %%
data= data.drop(columns = ['Serial No.'])
data.head()
# Out:
#     GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0  337.000000        118.0                4.0  4.5  4.5  9.65         1
# 1  324.000000        107.0                4.0  4.0  4.5  8.87         1
# 2  316.558763        104.0                3.0  3.0  3.5  8.00         1
# 3  322.000000        110.0                3.0  3.5  2.5  8.67         1
# 4  314.000000        103.0                2.0  2.0  3.0  8.21         0
#
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65

# %% [markdown]
# ### **EDA**

# %% [markdown]
# Let's visualize the data and analyze the relationship between independent and dependent variables:

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in data:
    if plotnumber<=16 :
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.tight_layout()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data distribution looks decent enough and there doesn't seem to be any skewness. Great let's go ahead!
#
# Let's observe the relationship between independent variables and dependent variable.

# %%
y = data['Chance of Admit']
X =data.drop(columns = ['Chance of Admit'])

# %%
X
# Out:
#       GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research
# 0    337.000000        118.0                4.0  4.5  4.5  9.65         1
# 1    324.000000        107.0                4.0  4.0  4.5  8.87         1
# 2    316.558763        104.0                3.0  3.0  3.5  8.00         1
# 3    322.000000        110.0                3.0  3.5  2.5  8.67         1
# 4    314.000000        103.0                2.0  2.0  3.0  8.21         0
# ..          ...          ...                ...  ...  ...   ...       ...
# 495  332.000000        108.0                5.0  4.5  4.0  9.02         1
# 496  337.000000        117.0                5.0  5.0  5.0  9.87         1
# 497  330.000000        120.0                5.0  4.5  5.0  9.56         1
# 498  312.000000        103.0                4.0  4.0  5.0  8.43         0
# 499  327.000000        113.0                4.0  4.5  4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit, Length: 500, dtype: float64

# %%
plt.figure(figsize=(20,30), facecolor='white')
plotnumber = 1

for column in X:
    if plotnumber<=15 :
        ax = plt.subplot(5,3,plotnumber)
        plt.scatter(X[column],y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Chance of Admit',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Great, the relationship between the dependent and independent variables look fairly linear.
# Thus, our linearity assumption is satisfied.
#
# Let's move ahead and check for multicollinearity.

# %% [markdown]
# ### **Feature Scaling**

# %%
scaler =StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = X_scaled

# we create a new data frame which will include all the VIFs
# note that each variable has its own variance inflation factor as this measure is variable specific (not model specific)
# we do not include categorical values for mulitcollinearity as they do not provide much information as numerical ones do
vif = pd.DataFrame()

# here we make use of the variance_inflation_factor, which will basically output the respective VIFs 
vif["VIF"] = [variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
# Finally, I like to include names so it is easier to explore the result
vif["Features"] = X.columns

# %%
vif
# Out:
#         VIF           Features
# 0  4.152735          GRE Score
# 1  3.793345        TOEFL Score
# 2  2.517272  University Rating
# 3  2.776393                SOP
# 4  2.037449                LOR
# 5  4.654369               CGPA
# 6  1.459411           Research

# %% [markdown]
# Here, we have the correlation values for all the features. As a thumb rule, a VIF value greater than 5 means a very severe multicollinearity. We don't any VIF greater than 5 , so we are good to go.
#
# Great. Let's go ahead and use linear regression and see how good it fits our data.
# But first. let's split our data in train and test.

# %%
x_train,x_test,y_train,y_test = train_test_split(X_scaled,y,test_size = 0.25,random_state=355)

# %%
y_train
# Out:
# 378    0.56
# 23     0.95
# 122    0.57
# 344    0.47
# 246    0.72
#        ...
# 51     0.56
# 291    0.56
# 346    0.47
# 130    0.96
# 254    0.85
# Name: Chance of Admit, Length: 375, dtype: float64

# %%
print("Shape of X train: ",x_train.shape)
print("Shape of X test: ",x_test.shape)
print("Shape of y train: ",y_train.shape)
print("Shape of y test: ",y_test.shape)
# Out:
# Shape of X train:  (375, 7)
# Shape of X test:  (125, 7)
# Shape of y train:  (375,)
# Shape of y test:  (125,)

# %% [markdown]
# # **Implementation of Machine Learning Start**

# %%
regression = LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# saving the model to the local file system
#filename = 'finalized_model.pickle'
#pickle.dump(regression, open(filename, 'wb'))

# %%
# prediction using the saved model
#loaded_model = pickle.load(open(filename, 'rb'))
#a=loaded_model.predict(scaler.transform([[300,110,5,5,5,10,1]]))
#a

# %%
regression.score(x_train,y_train)
# Out:
# 0.8415250484247909

# %%
# Let's create a function to create adjusted R-Squared
def adj_r2(x,y):
    r2 = regression.score(x,y)
    n = x.shape[0]
    p = x.shape[1]
    adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1)
    return adjusted_r2

# %%
adj_r2(x_train,y_train)
# Out:
# 0.8385023654247188

# %% [markdown]
# Our r2 score is 84.15% and adj r2 is 83.85% for our training et., so looks like we are not being penalized by use of any feature.
#
# Let's check how well model fits the test data.
#
# Now let's check if our model is overfitting our data using regularization.

# %%
regression.score(x_test,y_test)
# Out:
# 0.7534898831471066

# %%
adj_r2(x_test,y_test)
# Out:
# 0.7387414146174464

# %% [markdown]
# So it looks like our model r2 score is less on the test data.
#
# Let's see if our model is overfitting our training data.

# %%
# Lasso Regularization
# LassoCV will return best alpha and coefficients after performing 10 cross validations
lasscv = LassoCV(alphas = None,cv =10, max_iter = 100000, normalize = True)
lasscv.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# LassoCV(cv=10, max_iter=100000, normalize=True)

# %%
# best alpha parameter
alpha = lasscv.alpha_
alpha
# Out:
# 3.0341655445178153e-05

# %%
#now that we have best parameter, let's use Lasso regression and see how well our data has fitted before

lasso_reg = Lasso(alpha)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=3.0341655445178153e-05)

# %%
lasso_reg.score(x_test, y_test)
# Out:
# 0.7534654960492284

# %% [markdown]
# our r2_score for test data (75.34%) comes same as before using regularization. So, it is fair to say our OLS model did not overfit the data.

# %%
# Using Ridge regression model
# RidgeCV will return best alpha and coefficients after performing 10 cross validations. 
# We will pass an array of random numbers for ridgeCV to select best alpha from them

alphas = np.random.uniform(low=0, high=10, size=(50,))
ridgecv = RidgeCV(alphas = alphas,cv=10,normalize = True)
ridgecv.fit(x_train, y_train)
# Out:
# Streaming output truncated to the last 5000 lines.
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
# ...
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# RidgeCV(alphas=array([4.94452908, 4.33246866, 3.51365344, 0.94339251, 3.77315574,
#        6.22016972, 6.42756878, 1.35088526, 4.59411773, 4.9076442 ,
#        3.92389182, 1.96336958, 4.55938123, 2.21061077, 5.69413171,
#        2.38173795, 2.43026876, 4.38069093, 3.4418762 , 9.17350978,
#        1.33001791, 6.16108614, 1.07574227, 6.13359002, 8.60072275,
#        7.46239465, 3.89215261, 2.09961074, 9.76773478, 9.25921956,
#        4.21660982, 6.55240278, 3.4774941 , 2.13215531, 4.83492662,
#        3.46998568, 2.97103718, 8.52606753, 3.0198072 , 7.74623779,
#        3.62374277, 4.77685921, 0.42890659, 1.24416475, 1.38624895,
#        0.60032527, 0.2285709 , 3.4461681 , 7.59330317, 1.95357853]),
#         cv=10, normalize=True)

# %%
ridgecv.alpha_
# Out:
# 0.2285708990440416

# %%
ridge_model = Ridge(alpha=ridgecv.alpha_)
ridge_model.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.2285708990440416)

# %%
ridge_model.score(x_test, y_test)
# Out:
# 0.7536014210536472

# %% [markdown]
# we got the same r2 square using Ridge regression as well. So, it's safe to say there is no overfitting.

# %%
# Elastic net

elasticCV = ElasticNetCV(alphas = None, cv =10)

elasticCV.fit(x_train, y_train)
# Out:
# ElasticNetCV(cv=10)

# %%
elasticCV.alpha_
# Out:
# 0.0011069728449315508

# %%
# l1_ration gives how close the model is to L1 regularization, below value indicates we are giving equal
#preference to L1 and L2
elasticCV.l1_ratio
# Out:
# 0.5

# %%
elasticnet_reg = ElasticNet(alpha = elasticCV.alpha_,l1_ratio=0.5)
elasticnet_reg.fit(x_train, y_train)
# Out:
# ElasticNet(alpha=0.0011069728449315508)

# %%
elasticnet_reg.score(x_test, y_test)
# Out:
# 0.7531695370639867

# %% [markdown]
# # **Implementation of ANN Start**

# %%
# Importing the Keras libraries and packages
import tensorflow
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU,PReLU,ELU,ReLU
from tensorflow.keras.layers import Dropout

# %%
# Initialize the ANN

model = Sequential()

# %%
data.shape
# Out:
# (500, 8)

# %%
X.head()
# Out:
#     GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research
# 0  337.000000        118.0                4.0  4.5  4.5  9.65         1
# 1  324.000000        107.0                4.0  4.0  4.5  8.87         1
# 2  316.558763        104.0                3.0  3.0  3.5  8.00         1
# 3  322.000000        110.0                3.0  3.5  2.5  8.67         1
# 4  314.000000        103.0                2.0  2.0  3.0  8.21         0

# %%
# Adding the Input Layer
model.add(Dense(units = 7,activation="relu"))

# %%
# Adding the First Hidden Layer
model.add(Dense(units = 7,activation="relu"))
model.add(Dropout(0.2))

# %%
# Adding the Second Hidden Layer
model.add(Dense(units = 6,activation="relu"))
model.add(Dropout(0.3))

# %%
# Adding the Output Layer
model.add(Dense(units = 1,activation="linear"))

# %%
model.compile(optimizer="adam",loss="mean_squared_error")

# %%
# Now train the Model
history = model.fit(x_train,y_train,epochs = 1000,validation_split = 0.2)
# Out:
# Epoch 1/1000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0213 - val_loss: 0.0111
# Epoch 2/1000
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0212 - val_loss: 0.0110
# Epoch 3/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0180 - val_loss: 0.0109
# Epoch 4/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0193 - val_loss: 0.0113
# Epoch 5/1000
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0214 - val_loss: 0.0113
# Epoch 6/1000
# 10/10 [==============================] - 0s 9ms/step - loss: 0.
1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0122 - val_loss: 0.0085
# Epoch 76/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - val_loss: 0.0085
# Epoch 77/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0110 - val_loss: 0.0088
# Epoch 78/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0116 - val_loss: 0.0088
# Epoch 79/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0109 - val_loss: 0.0086
# Epoch 80/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0117 - val_loss: 0.0086
# Epoch 81/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0086
# Epoch 82/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0108 - val_loss: 0.0086
# Epoch 83/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.0086
# Epoch 84/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0114 - val_loss: 0.0086
# Epoch 85/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.0087
# Epoch 86/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0100 - val_loss: 0.0085
# Epoch 87/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0109 - val_loss: 0.0086
# Epoch 88/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0110 - val_loss: 0.0086
# Epoch 89/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0104 - val_loss: 0.0083
# Epoch 90/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0084
# Epoch 91/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0107 - val_loss: 0.0081
# Epoch 92/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0100 - val_loss: 0.0080
# Epoch 93/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0078
# Epoch 94/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0101 - val_loss: 0.0084
# Epoch 95/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0104 - val_loss: 0.0087
# Epoch 96/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.0089
# Epoch 97/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0090
# Epoch 98/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0086
# Epoch 99/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0081
# Epoch 100/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0105 - val_loss: 0.0082
# Epoch 101/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0085
# Epoch 102/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0105 - val_loss: 0.0087
# Epoch 103/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0088
# Epoch 104/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0093 - val_loss: 0.0085
# Epoch 105/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0082
# Epoch 106/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0080
# Epoch 107/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0093 - val_loss: 0.0080
# Epoch 108/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0081
# Epoch 109/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0092 - val_loss: 0.0085
# Epoch 110/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.0087
# Epoch 111/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0108 - val_loss: 0.0088
# Epoch 112/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0090
# Epoch 113/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0086
# Epoch 114/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0085 - val_loss: 0.0085
# Epoch 115/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0082
# Epoch 116/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0096 - val_loss: 0.0082
# Epoch 117/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0082
# Epoch 118/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0084
# Epoch 119/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0092 - val_loss: 0.0085
# Epoch 120/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0082
# Epoch 121/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0086 - val_loss: 0.0082
# Epoch 122/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0082
# Epoch 123/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0083
# Epoch 124/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0087
# Epoch 125/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0093 - val_loss: 0.0084
# Epoch 126/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0080
# Epoch 127/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0088 - val_loss: 0.0078
# Epoch 128/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0079
# Epoch 129/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0092 - val_loss: 0.0079
# Epoch 130/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0106 - val_loss: 0.0080
# Epoch 131/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0082
# Epoch 132/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0083
# Epoch 133/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0093 - val_loss: 0.0082
# Epoch 134/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0082
# Epoch 135/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0081
# Epoch 136/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0087 - val_loss: 0.0085
# Epoch 137/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0087
# Epoch 138/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0085
# Epoch 139/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0093 - val_loss: 0.0085
# Epoch 140/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0082
# Epoch 141/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0083
# Epoch 142/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0080
# Epoch 143/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0075
# Epoch 144/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0092 - val_loss: 0.0076
# Epoch 145/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0082 - val_loss: 0.0079
# Epoch 146/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0084 - val_loss: 0.0082
# Epoch 147/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0084
# Epoch 148/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0100 - val_loss: 0.0086
# Epoch 149/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0096 - val_loss: 0.0083
# Epoch 150/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0090 - val_loss: 0.0080
# Epoch 151/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0085 - val_loss: 0.0079
# Epoch 152/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0079
# Epoch 153/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0079
# Epoch 154/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0082
# Epoch 155/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0084
# Epoch 156/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.0082
# Epoch 157/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0080
# Epoch 158/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0078
# Epoch 159/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0077
# Epoch 160/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0077
# Epoch 161/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0081
# Epoch 162/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0082
# Epoch 163/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0084 - val_loss: 0.0080
# Epoch 164/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0082
# Epoch 165/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0079
# Epoch 166/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0076
# Epoch 167/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0090 - val_loss: 0.0075
# Epoch 168/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0081 - val_loss: 0.0078
# Epoch 169/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0085 - val_loss: 0.0080
# Epoch 170/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0079
# Epoch 171/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0080 - val_loss: 0.0078
# Epoch 172/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0077
# Epoch 173/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0078
# Epoch 174/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0081
# Epoch 175/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.0079
# Epoch 176/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.0081
# Epoch 177/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0079
# Epoch 178/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.0077
# Epoch 179/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0084 - val_loss: 0.0079
# Epoch 180/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0096 - val_loss: 0.0079
# Epoch 181/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0079
# Epoch 182/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0079 - val_loss: 0.0079
# Epoch 183/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.0079
# Epoch 184/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0079
# Epoch 185/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0096 - val_loss: 0.0078
# Epoch 186/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0092 - val_loss: 0.0076
# Epoch 187/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0077
# Epoch 188/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0081 - val_loss: 0.0080
# Epoch 189/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0078
# Epoch 190/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0077
# Epoch 191/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0084 - val_loss: 0.0079
# Epoch 192/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0084 - val_loss: 0.0081
# Epoch 193/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0078 - val_loss: 0.0079
# Epoch 194/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0078
# Epoch 195/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0077 - val_loss: 0.0080
# Epoch 196/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0091 - val_loss: 0.0081
# Epoch 197/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0082
# Epoch 198/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0090 - val_loss: 0.0080
# Epoch 199/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0081 - val_loss: 0.0076
# Epoch 200/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0092 - val_loss: 0.0072
# Epoch 201/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0078 - val_loss: 0.0074
# Epoch 202/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0077 - val_loss: 0.0074
# Epoch 203/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0074
# Epoch 204/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.0075
# Epoch 205/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0079 - val_loss: 0.0076
# Epoch 206/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0083 - val_loss: 0.0078
# Epoch 207/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.0075
# Epoch 208/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.0071
# Epoch 209/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0078 - val_loss: 0.0070
# Epoch 210/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0079 - val_loss: 0.0070
# Epoch
1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 417/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 0.0068
# Epoch 418/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0073 - val_loss: 0.0067
# Epoch 419/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0075 - val_loss: 0.0060
# Epoch 420/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.0063
# Epoch 421/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0062
# Epoch 422/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.0063
# Epoch 423/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.0066
# Epoch 424/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0065 - val_loss: 0.0062
# Epoch 425/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.0066
# Epoch 426/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0068
# Epoch 427/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 428/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0065 - val_loss: 0.0063
# Epoch 429/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0071 - val_loss: 0.0065
# Epoch 430/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0061
# Epoch 431/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 432/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.0065
# Epoch 433/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0065 - val_loss: 0.0063
# Epoch 434/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 435/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 436/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.0067
# Epoch 437/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 438/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0066 - val_loss: 0.0061
# Epoch 439/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0065 - val_loss: 0.0063
# Epoch 440/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0065 - val_loss: 0.0066
# Epoch 441/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.0063
# Epoch 442/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0057 - val_loss: 0.0059
# Epoch 443/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.0063
# Epoch 444/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 445/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 446/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0074 - val_loss: 0.0060
# Epoch 447/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0066
# Epoch 448/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 449/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0060
# Epoch 450/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0062 - val_loss: 0.0058
# Epoch 451/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 452/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0064
# Epoch 453/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 0.0060
# Epoch 454/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.0058
# Epoch 455/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 456/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 0.0064
# Epoch 457/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 458/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0075 - val_loss: 0.0062
# Epoch 459/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 460/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0058
# Epoch 461/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0065
# Epoch 462/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0075 - val_loss: 0.0067
# Epoch 463/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0070 - val_loss: 0.0058
# Epoch 464/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0064
# Epoch 465/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0068
# Epoch 466/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0066 - val_loss: 0.0060
# Epoch 467/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0072 - val_loss: 0.0057
# Epoch 468/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0059
# Epoch 469/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0059
# Epoch 470/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0073 - val_loss: 0.0054
# Epoch 471/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0058
# Epoch 472/1000
# ...
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.0061
# Epoch 845/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0058
# Epoch 846/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 847/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0070 - val_loss: 0.0061
# Epoch 848/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 849/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0065
# Epoch 850/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0062 - val_loss: 0.0067
# Epoch 851/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0065
# Epoch 852/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0059
# Epoch 853/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0059
# Epoch 854/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 855/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0061
# Epoch 856/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 857/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 858/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0058
# Epoch 859/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0054 - val_loss: 0.0065
# Epoch 860/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0061
# Epoch 861/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0061
# Epoch 862/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0061
# Epoch 863/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0056
# Epoch 864/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0058 - val_loss: 0.0064
# Epoch 865/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.0062
# Epoch 866/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0057
# Epoch 867/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0062
# Epoch 868/1000
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0059 - val_loss: 0.0062
# Epoch 869/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0065
# Epoch 870/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0076 - val_loss: 0.0066
# Epoch 871/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 872/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 873/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 874/1000
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0055 - val_loss: 0.0065
# Epoch 875/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0068 - val_loss: 0.0063
# Epoch 876/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0065 - val_loss: 0.0062
# Epoch 877/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 878/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0060
# Epoch 879/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0065
# Epoch 880/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0062
# Epoch 881/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 882/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0054
# Epoch 883/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 884/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0062 - val_loss: 0.0064
# Epoch 885/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0059
# Epoch 886/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 887/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.0061
# Epoch 888/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0064
# Epoch 889/1000
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0059
# Epoch 890/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.0059
# Epoch 891/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0061
# Epoch 892/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 893/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 894/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 895/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.0059
# Epoch 896/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.0058
# Epoch 897/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 898/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 899/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 900/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0060
# Epoch 901/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 902/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0065 - val_loss: 0.0065
# Epoch 903/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 904/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0066
# Epoch 905/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 906/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0072 - val_loss: 0.0063
# Epoch 907/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0066 - val_loss: 0.0064
# Epoch 908/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 0.0064
# Epoch 909/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0060
# Epoch 910/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 911/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0056
# Epoch 912/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0065 - val_loss: 0.0059
# Epoch 913/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0059
# Epoch 914/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 915/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0068
# Epoch 916/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0065 - val_loss: 0.0067
# Epoch 917/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 918/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0059
# Epoch 919/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 920/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 921/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 922/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.0065
# Epoch 923/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0060
# Epoch 924/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0058
# Epoch 925/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0063
# Epoch 926/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0067
# Epoch 927/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 928/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0062 - val_loss: 0.0060
# Epoch 929/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 930/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0060
# Epoch 931/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0065 - val_loss: 0.0056
# Epoch 932/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0067
# Epoch 933/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0065 - val_loss: 0.0070
# Epoch 934/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0062
# Epoch 935/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0061
# Epoch 936/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0057 - val_loss: 0.0063
# Epoch 937/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0065
# Epoch 938/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.0065
# Epoch 939/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0063
# Epoch 940/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 941/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0062
# Epoch 942/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0064
# Epoch 943/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 944/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.0064
# Epoch 945/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0063
# Epoch 946/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 947/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 948/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 949/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 950/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0058 - val_loss: 0.0057
# Epoch 951/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0066 - val_loss: 0.0064
# Epoch 952/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.0069
# Epoch 953/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 954/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0060
# Epoch 955/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 956/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0069
# Epoch 957/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0062
# Epoch 958/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0060
# Epoch 959/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0063
# Epoch 960/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0064
# Epoch 961/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0070
# Epoch 962/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0070 - val_loss: 0.0060
# Epoch 963/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0059
# Epoch 964/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0067
# Epoch 965/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.0069
# Epoch 966/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0066
# Epoch 967/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0065 - val_loss: 0.0062
# Epoch 968/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0060
# Epoch 969/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.0062
# Epoch 970/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0066
# Epoch 971/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0072
# Epoch 972/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0065
# Epoch 973/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 974/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0054 - val_loss: 0.0060
# Epoch 975/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0062
# Epoch 976/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 977/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 978/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0062
# Epoch 979/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0063
# Epoch 980/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0061
# Epoch 981/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0059
# Epoch 982/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 983/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0054 - val_loss: 0.0069
# Epoch 984/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 985/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 986/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0058
# Epoch 987/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 988/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0073 - val_loss: 0.0065
# Epoch 989/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0068 - val_loss: 0.0068
# Epoch 990/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0065 - val_loss: 0.0061
# Epoch 991/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0063
# Epoch 992/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.0060
# Epoch 993/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0061 - val_loss: 0.0067
# Epoch 994/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0065
# Epoch 995/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0058
# Epoch 996/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 997/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0057
# Epoch 998/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 999/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0058 - val_loss: 0.0059
# Epoch 1000/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.0063

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 7)                 56
#
#  dense_1 (Dense)             (None, 7)                 56
#
#  dropout (Dropout)           (None, 7)                 0
#
#  dense_2 (Dense)             (None, 6)                 48
#
#  dropout_1 (Dropout)         (None, 6)                 0
#
#  dense_3 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 167
# Trainable params: 167
# Non-trainable params: 0
# _________________________________________________________________

# %%
# list all data in history

print(history.history.keys())
# Out:
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# #### **Prediction of Model**

# %%
y_pred = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import r2_score
r2_score(y_pred,y_test)
# Out:
# 0.2253235240813738

# %%
# summarize history for loss
plt.figure(figsize=(15,7))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss',fontsize=15)
plt.ylabel('Loss',fontsize=12)
plt.xlabel('Epoch',fontsize=12)
plt.legend(['train', 'test'], loc='upper left')
plt.show()
